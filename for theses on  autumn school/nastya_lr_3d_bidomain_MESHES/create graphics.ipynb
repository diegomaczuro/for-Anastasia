# %%
# -*- coding: utf_8 -*-
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import vtk
from vtk import *
from vtk.util import numpy_support
import matplotlib.pylab as plt
import os
import imp
import h5py
from sklearn.neighbors import KDTree
from tqdm import tqdm
from sklearn.neighbors import KDTree
from vtk.util.numpy_support import vtk_to_numpy
from vtk.util.numpy_support import numpy_to_vtk
import matplotlib.pylab as plt
# %matplotlib inline

# %%
FOLDER_3D = 'nastya_lr_3d_bidomain'
FOLDER_2D = 'nastya_lr_2d_bidomain'
FOLDER_RESULTS = 'result_luorudy1991'
WAY = '/home/shido/Documents/shido/for Anastasia/for-Anastasia/for theses on  autumn school/'
FILE_H5 = 'results.h5'
FILE_MESH_TURN = 'slice_mesh2.vtk'
FILE_MESH = 'init_mesh_1.vtu'
FILE_OUT = 'out.vtu'
FILE_RESULT_DIFFERCE = 'result_difference_V{ind}.vtu'
FILE_RESULT_ARRAY = 'V.txt'
assert(os.path.exists(os.path.join(WAY, FOLDER_RESULTS, 'V.npy')))

# %%
diff_V = np.load(os.path.join(WAY, FOLDER_RESULTS, 'V.npy'))
diff_V_phi = np.load(os.path.join(WAY, FOLDER_RESULTS, 'V_phi.npy'))

# %%
len(diff_V)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-34dcb1acf44c> in <module>()
# ----> 1 len(diff_V)
#
# NameError: name 'diff_V' is not defined

# %%
diff_I_stim = np.load(os.path.join(WAY, FOLDER_RESULTS, 'I_stim.npy'))
diff_I_Na = np.load(os.path.join(WAY, FOLDER_RESULTS, 'I_Na.npy'))
diff_I_si = np.load(os.path.join(WAY, FOLDER_RESULTS, 'I_si.npy'))
diff_I_K = np.load(os.path.join(WAY, FOLDER_RESULTS, 'I_K.npy'))
diff_I_K1 = np.load(os.path.join(WAY, FOLDER_RESULTS, 'I_K1.npy'))
diff_I_Kp = np.load(os.path.join(WAY, FOLDER_RESULTS, 'I_Kp.npy'))
diff_I_b = np.load(os.path.join(WAY, FOLDER_RESULTS, 'I_b.npy'))
max_l = max(max(diff_I_Na), max(diff_I_si), max(diff_I_K), max(diff_I_K1), max(diff_I_Kp), max(diff_I_b))
max_l
# Out:
# 4789.8179520431495

# %%
plt.xlabel('Time (ms) - t')
plt.ylabel('Difference V (mV)')
plt.plot(diff_V/max_l)
plt.savefig(os.path.join(WAY, FOLDER_2D, FOLDER_RESULT, 'Difference V.png'))

# %%
plt.xlabel('Time (ms) - t')
plt.ylabel('Difference V_phi (mV)')
plt.plot(diff_V_phi/max_l)
plt.savefig(os.path.join(WAY, FOLDER_2D, FOLDER_RESULT, 'Difference V_phi.png'))

# %%
print len(diff_I_stim)
plt.xlabel('Time (ms) - t')
plt.ylabel('Difference I_stim (mV)')
plt.plot(diff_I_stim/max_l)
plt.savefig(os.path.join(WAY, FOLDER_2D, FOLDER_RESULT, 'Difference I_stim.png'))
# Out:
# 501

# %%
plt.xlabel('Time (ms) - t')
plt.ylabel('Difference I_Na (mV)')
plt.plot(diff_I_Na/max_l)
plt.savefig(os.path.join(WAY, FOLDER_2D, FOLDER_RESULT, 'Difference I_Na.png'))

# %%
plt.xlabel('Time (ms) - t')
plt.ylabel('Difference I_si (mV)')
plt.plot(diff_I_si/max_l)
plt.savefig(os.path.join(WAY, FOLDER_2D, FOLDER_RESULT, 'Difference I_si.png'))

# %%
plt.xlabel('Time (ms) - t')
plt.ylabel('Difference I_K (mV)')
plt.plot(diff_I_K/max_l)
plt.savefig(os.path.join(WAY, FOLDER_2D, FOLDER_RESULT, 'Difference I_K.png'))

# %%
plt.xlabel('Time (ms) - t')
plt.ylabel('Difference I_K1 (mV)')
plt.plot(diff_I_K1/max_l)
plt.savefig(os.path.join(WAY, FOLDER_2D, FOLDER_RESULT, 'Difference I_K1.png'))

# %%
plt.xlabel('Time (ms) - t')
plt.ylabel('Difference I_Kp (mV)')
plt.plot(diff_I_Kp/max_l)
plt.savefig(os.path.join(WAY, FOLDER_2D, FOLDER_RESULT, 'Difference I_Kp.png'))

# %%
plt.xlabel('Time (ms) - t')
plt.ylabel('Difference I_b (mV)')
plt.plot(diff_I_b/max_l)
plt.savefig(os.path.join(WAY, FOLDER_2D, FOLDER_RESULT, 'Difference I_b.png'))

# %%
max_l = np.max([diff_I_si, diff_I_K, diff_I_K1, diff_I_Kp, diff_I_b])

#plt.plot(diff_V/max_l)
#plt.plot(diff_V_phi/max_l)
fig = plt.figure()
ax = plt.subplot(111)
#ax.plot(diff_V/max_l, label='diff_V')
#ax.plot(diff_V_phi/max_l, label='diff_V_phi')
#ax.plot(diff_I_stim/max_l, label='diff_I_stim')
#ax.plot(diff_I_Na/max_l, label='diff_I_Na')
ax.plot(diff_I_si/max_l, label='diff_I_si')
ax.plot(diff_I_K/max_l, label='diff_I_K')
ax.plot(diff_I_K1/max_l, label='diff_I_K1')
ax.plot(diff_I_Kp/max_l, label='diff_I_Kp')
ax.plot(diff_I_b/max_l, label='diff_I_b')
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.savefig(os.path.join(WAY, FOLDER_RESULTS, 'General results4.png'))
print 'I_b', max(diff_I_b)*100/max(diff_I_Na), '%'
print 'I_si', max(diff_I_si)*100/max(diff_I_Na), '%'
print 'I_K', max(diff_I_K)*100/max(diff_I_Na), '%'
print 'I_K1', max(diff_I_K1)*100/max(diff_I_Na), '%'
print 'I_Kp', max(diff_I_Kp)*100/max(diff_I_Na), '%'
print 'I_Na', 100 - max(diff_I_b)*100/max(diff_I_Na) - max(diff_I_si)*100/max(diff_I_Na) - max(diff_I_K)*100/max(diff_I_Na)- max(diff_I_K1)*100/max(diff_I_Na)-max(diff_I_Kp)*100/max(diff_I_Na), '%'
# Out:
# I_b 1.76705730554 %
# I_si 0.459582684741 %
# I_K 0.351423422445 %
# I_K1 0.870046281744 %
# I_Kp 0.976709567135 %
# I_Na 95.5751807384 %

# %%
max_rep = np.max([diff_I_b[200:]+diff_I_K[200:]+diff_I_si[200:]+diff_I_K1[200:]])
print 'I_b', max(diff_I_b[200:])*100/max_rep, '%'
print 'I_si', max(diff_I_si[200:])*100/max_rep, '%'
print 'I_K', max(diff_I_K[200:])*100/max_rep, '%'
print 'I_K1', max(diff_I_K1[200:])*100/max_rep, '%'
#print 'I_Kp', max(diff_I_Kp[200:]/max_rep)*100/max_rep, '%'
print max_rep, max(diff_I_b[200:]), max(diff_I_Na[200:])
# Out:
# I_b 21.6934034174 %
# I_si 25.1141923505 %
# I_K 26.7773566044 %
# I_K1 33.6551974495 %
# 28.5104695216 6.18489116952 0.00899125475712

# %%
max_l = np.max([diff_V, diff_I_si, diff_I_K, diff_I_K1, diff_I_Kp, diff_I_b])

#plt.plot(diff_V/max_l)
#plt.plot(diff_V_phi/max_l)
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(diff_V/max_l, label='diff_V')
#ax.plot(diff_I_Na/max_l, label='diff_I_Na')
ax.plot((diff_I_si+diff_I_K+diff_I_K1+diff_I_Kp+diff_I_b)/max_l, label='diff_summ_ion')
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.savefig(os.path.join(WAY, FOLDER_2D, FOLDER_RESULT, 'General results4.png'))

# %%
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(diff_V/(max(diff_V)), label='diff_V')
ax.plot(diff_V_phi/max(diff_V_phi), label='diff_V_phi')
ax.plot(diff_I_stim/max(diff_I_stim), label='diff_I_stim')
ax.plot(diff_I_Na/max(diff_I_Na), label='diff_I_Na')
ax.plot(diff_I_si/max(diff_I_si), label='diff_I_si')
ax.plot(diff_I_K/max(diff_I_K), label='diff_I_K')
ax.plot(diff_I_K1/max(diff_I_K1), label='diff_I_K1')
ax.plot(diff_I_Kp/max(diff_I_Kp), label='diff_I_Kp')
ax.plot(diff_I_b/max(diff_I_b), label='diff_I_b')
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.savefig(os.path.join(WAY, FOLDER_2D, FOLDER_RESULT, 'General results.png'))
plt.show()

# %%
#max_l = np.max([diff_I_si[50:], diff_I_K[50:], diff_I_K1[50:], diff_I_Kp[50:], diff_I_b[50:], diff_I_Na[50:]])
max_l = max(diff_I_si[50:])+max(diff_I_K[50:])+max(diff_I_K1[50:])+max(diff_I_Kp[50:]) +max(diff_I_b[50:])+max(diff_I_Na[50:])
#plt.plot(diff_V/max_l)
#plt.plot(diff_V_phi/max_l)
fig = plt.figure()
ax = plt.subplot(111)
#ax.plot(diff_V/max_l, label='diff_V')
#ax.plot(diff_V_phi/max_l, label='diff_V_phi')
#ax.plot(diff_I_stim/max_l, label='diff_I_stim')
ax.plot(diff_I_Na/max_l, label='diff_I_Na')
ax.plot(diff_I_si/max_l, label='diff_I_si')
ax.plot(diff_I_K/max_l, label='diff_I_K')
ax.plot(diff_I_K1/max_l, label='diff_I_K1')
ax.plot(diff_I_Kp/max_l, label='diff_I_Kp')
ax.plot(diff_I_b/max_l, label='diff_I_b')
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.savefig(os.path.join(WAY, FOLDER_RESULTS, 'General results.png'))
print 'I_b', max(diff_I_b[50:])*100/max_l, '%'
print 'I_si', max(diff_I_si[50:])*100/max_l, '%'
print 'I_K', max(diff_I_K[50:])*100/max_l, '%'
print 'I_K1', max(diff_I_K1[50:])*100/max_l, '%'
print 'I_Kp', max(diff_I_Kp[50:])*100/max_l, '%'
print 'I_Na', max(diff_I_Na[50:])*100/max_l, '%'
# Out:
# I_b 19.2344296654 %
# I_si 22.2674679981 %
# I_K 23.7421105542 %
# I_K1 29.8403397457 %
# I_Kp 4.88769008016 %
# I_Na 0.0279619564014 %

# %%
19+20+23+29+4
# Out:
# 95

# %%
max(diff_I_si[50:])+max(diff_I_K[50:])+max(diff_I_K1[50:])+max(diff_I_Kp[50:]) +max(diff_I_b[50:])+max(diff_I_Na[50:])
# Out:
# 32.155313555496065

# %%
a = [1,2,3,4,5,6]
a[2:]
# Out:
# [3, 4, 5, 6]
